# %%
# Setup google drive
from google.colab import drive
import sys

# Mount google drive filesystem
drive.mount('/content/drive', force_remount=True)

# Add current folder to path
ROOT = '/content/drive/My Drive/UniPD/2019_20_Business_Economic_Financial_Data_BEFD/PJM'
sys.path.append(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Libraries
import numpy as np
import pandas as pd
import torch
from modules.energy_consumption_net import EnergyConsumptionNet, train_epochs
from modules.energy_consumption_dataset import EnergyConsumptionDataset
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import matplotlib.colors as mc

# Register converters to plot datetime axis
pd.plotting.register_matplotlib_converters()

# Setup matplotlib plotting
# %matplotlib inline

# %%
# Read dataset
ds = pd.read_csv(ROOT + '/data/ready.csv', parse_dates=['datetime'], index_col='datetime')
# We want to have 2018 in last positions of the array (due to Neural Network layout)
# So, dataset is sorted accordingly
ds.sort_index(ascending=True, inplace=True)
# Show dataset
ds.head()
# Out:
#                          AEP  DAYTON     DOM     DUQ
# datetime
# 2006-01-01 00:00:00  14565.0  1769.0  9649.0  1493.0
# 2006-01-01 01:00:00  14287.0  1697.0  9258.0  1255.0
# 2006-01-01 02:00:00  13932.0  1635.0  8987.0  1338.0
# 2006-01-01 03:00:00  13713.0  1584.0  8781.0  1276.0
# 2006-01-01 04:00:00  13656.0  1553.0  8680.0  1251.0

# %%
# Since we want a univariate predictor, we use only AEP time series
aep = ds.AEP
aep.head()
# Out:
# datetime
# 2006-01-01 00:00:00    14565.0
# 2006-01-01 01:00:00    14287.0
# 2006-01-01 02:00:00    13932.0
# 2006-01-01 03:00:00    13713.0
# 2006-01-01 04:00:00    13656.0
# Name: AEP, dtype: float64

# %%
# Plot the time series
fig, ax = plt.subplots(figsize=(21, 7))
_ = ax.set_title('Hourly MWh consumption, AEP region')
_ = ax.plot(aep, '-')
_ = ax.axhline(y=aep.mean(), color='red', ls='--')
# Show plot
_ = plt.show()

# %%
# Time series additive decomposition
aep_decomposed = seasonal_decompose(aep, model='additive', freq=365*24)

# Make plot
fig, axs = plt.subplots(3, 1, figsize=(21, 15))
_ = plt.title('Seasonal decomposition (additive model)')  # Define title
# Plot trend component
_ = axs[0].set_title('Trend')
_ = axs[0].plot(aep.index, aep_decomposed.trend, '-')
# Plot seasonal component
_ = axs[1].set_title('Seasonal')
_ = axs[1].plot(aep.index, aep_decomposed.seasonal, '-')
# Plot residual component
_ = axs[2].set_title('Residual')
_ = axs[2].plot(aep.index, aep_decomposed.resid,  '-')
# Show plot
_ = plt.show()

# %%
# Compute (Partial) Autocorrelation Function

# Define number of lags backward
nlags = 50

# Plot either ACF and PACF
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
# ACF plot
_ = plot_acf(aep, lags=50, fft=True, ax=axs[0])
# PACF plot
_ = plot_pacf(aep, lags=50, ax=axs[1])
# Show plot
_ = plt.show()

# %%
# Split original dataset into training and testing
train = ds.loc[:'2017-01-01 00:00:00']
test = ds.loc['2017-01-01 00:00:00':]

# Check train and test datasets
print('Train dataset has {:d} rows ({:.0f}%)'.format(train.shape[0], train.shape[0] / ds.shape[0] * 100))
print('Test dataset has {:d} rows ({:.0f}%)'.format(test.shape[0], test.shape[0] / ds.shape[0] * 100))
# Out:
# Train dataset has 96433 rows (87%)
# Test dataset has 13897 rows (13%)

# %%
# Define PyTorch Datasets
lag = 3  # Lag
train = EnergyConsumptionDataset(train[['AEP']], lag=lag)
test = EnergyConsumptionDataset(test[['AEP']], col_max=train.max, col_min=train.min, lag=lag)

# %%
# Define network (10 lags)
ecnet3 = EnergyConsumptionNet(input_size=1, hidden_size=128, num_layers=2, dropout=0.3)
# Move net to GPU
ecnet3.to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
# Out:
# EnergyConsumptionNet(
#   (rnn): LSTM(1, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# Train the net
train_loss = train_epochs(
    net=ecnet3, dataset=train, batch_size=10000, num_epochs=250, 
    optimizer=torch.optim.Adagrad(ecnet3.parameters()),
    verbose=True
)

# Save training loss
np.save(ROOT + '/models/univariate.npy', train_loss)

# Save the network to disk
torch.save(ecnet3.state_dict(), ROOT + '/models/univariate.pt')
# Out:
# Epoch nr 0001 with mean loss: 0.06198
# Epoch nr 0002 with mean loss: 0.02141
# Epoch nr 0003 with mean loss: 0.01524
# Epoch nr 0004 with mean loss: 0.01072
# Epoch nr 0005 with mean loss: 0.00777
# Epoch nr 0006 with mean loss: 0.00683
# Epoch nr 0007 with mean loss: 0.00624
# Epoch nr 0008 with mean loss: 0.00601
# Epoch nr 0009 with mean loss: 0.00594
# Epoch nr 0010 with mean loss: 0.00580
# Epoch nr 0011 with mean loss: 0.00574
# Epoch nr 0012 with mean loss: 0.00573
# Epoch nr 0013 with mean loss: 0.00561
# Epoch nr 0014 with mean loss: 0.00558
# Epoch nr 0015 with mean loss: 0.00553
# Epoch nr 0016 with mean loss: 0.00550
# Epoch nr 0017 with mean loss: 0.00544
# Epoch nr 0018 with mean loss: 0.00540
# Epoch nr 0019 with mean loss: 0.00537
# Epoch nr 0020 with mean loss: 0.00533
# Epoch nr 0021 with mean loss: 0.00528
# Epoch nr 0022 with mean loss: 0.00523
# Epoch nr 0023 with mean loss: 0.00517
# Epoch nr 0024 with mean loss: 0.00513
# Epoch nr 0025 with mean loss: 0.00509
# Epoch nr 0026 with mean loss: 0.00505
# Epoch nr 0027 with mean loss: 0.00497
# Epoch nr 0028 with mean loss: 0.00495
# Epoch nr 0029 with mean loss: 0.00489
# Epoch nr 0030 with mean loss: 0.00486
# Epoch nr 0031 with mean loss: 0.00480
# Epoch nr 0032 with mean loss: 0.00477
# Epoch nr 0033 with mean loss: 0.00472
# Epoch nr 0034 with mean loss: 0.00463
# Epoch nr 0035 with mean loss: 0.00459
# Epoch nr 0036 with mean loss: 0.00459
# Epoch nr 0037 with mean loss: 0.00453
# Epoch nr 0038 with mean loss: 0.00447
# Epoch nr 0039 with mean loss: 0.00442
# Epoch nr 0040 with mean loss: 0.00435
# Epoch nr 0041 with mean loss: 0.00431
# Epoch nr 0042 with mean loss: 0.00428
# Epoch nr 0043 with mean loss: 0.00419
# Epoch nr 0044 with mean loss: 0.00414
# Epoch nr 0045 with mean loss: 0.00417
# Epoch nr 0046 with mean loss: 0.00409
# Epoch nr 0047 with mean loss: 0.00401
# Epoch nr 0048 with mean loss: 0.00391
# Epoch nr 0049 with mean loss: 0.00382
# Epoch nr 0050 with mean loss: 0.00379
# Epoch nr 0051 with mean loss: 0.00376
# Epoch nr 0052 with mean loss: 0.00372
# Epoch nr 0053 with mean loss: 0.00366
# Epoch nr 0054 with mean loss: 0.00353
# Epoch nr 0055 with mean loss: 0.00354
# Epoch nr 0056 with mean loss: 0.00347
# Epoch nr 0057 with mean loss: 0.00336
# Epoch nr 0058 with mean loss: 0.00327
# Epoch nr 0059 with mean loss: 0.00331
# Epoch nr 0060 with mean loss: 0.00324
# Epoch nr 0061 with mean loss: 0.00316
# Epoch nr 0062 with mean loss: 0.00308
# Epoch nr 0063 with mean loss: 0.00294
# Epoch nr 0064 with mean loss: 0.00288
# Epoch nr 0065 with mean loss: 0.00295
# Epoch nr 0066 with mean loss: 0.00283
# Epoch nr 0067 with mean loss: 0.00279
# Epoch nr 0068 with mean loss: 0.00267
# Epoch nr 0069 with mean loss: 0.00253
# Epoch nr 0070 with mean loss: 0.00257
# Epoch nr 0071 with mean loss: 0.00247
# Epoch nr 0072 with mean loss: 0.00252
# Epoch nr 0073 with mean loss: 0.00235
# Epoch nr 0074 with mean loss: 0.00231
# Epoch nr 0075 with mean loss: 0.00221
# Epoch nr 0076 with mean loss: 0.00216
# Epoch nr 0077 with mean loss: 0.00220
# Epoch nr 0078 with mean loss: 0.00206
# Epoch nr 0079 with mean loss: 0.00203
# Epoch nr 0080 with mean loss: 0.00198
# Epoch nr 0081 with mean loss: 0.00188
# Epoch nr 0082 with mean loss: 0.00198
# Epoch nr 0083 with mean loss: 0.00189
# Epoch nr 0084 with mean loss: 0.00179
# Epoch nr 0085 with mean loss: 0.00170
# Epoch nr 0086 with mean loss: 0.00174
# Epoch nr 0087 with mean loss: 0.00173
# Epoch nr 0088 with mean loss: 0.00164
# Epoch nr 0089 with mean loss: 0.00165
# Epoch nr 0090 with mean loss: 0.00153
# Epoch nr 0091 with mean loss: 0.00144
# Epoch nr 0092 with mean loss: 0.00157
# Epoch nr 0093 with mean loss: 0.00153
# Epoch nr 0094 with mean loss: 0.00142
# Epoch nr 0095 with mean loss: 0.00146
# Epoch nr 0096 with mean loss: 0.00139
# Epoch nr 0097 with mean loss: 0.00146
# Epoch nr 0098 with mean loss: 0.00141
# Epoch nr 0099 with mean loss: 0.00128
# Epoch nr 0100 with mean loss: 0.00132
# Epoch nr 0101 with mean loss: 0.00129
# Epoch nr 0102 with mean loss: 0.00124
# Epoch nr 0103 with mean loss: 0.00129
# Epoch nr 0104 with mean loss: 0.00128
# Epoch nr 0105 with mean loss: 0.00126
# Epoch nr 0106 with mean loss: 0.00117
# Epoch nr 0107 with mean loss: 0.00119
# Epoch nr 0108 with mean loss: 0.00118
# Epoch nr 0109 with mean loss: 0.00112
# Epoch nr 0110 with mean loss: 0.00119
# Epoch nr 0111 with mean loss: 0.00119
# Epoch nr 0112 with mean loss: 0.00111
# Epoch nr 0113 with mean loss: 0.00112
# Epoch nr 0114 with mean loss: 0.00113
# Epoch nr 0115 with mean loss: 0.00110
# Epoch nr 0116 with mean loss: 0.00110
# Epoch nr 0117 with mean loss: 0.00106
# Epoch nr 0118 with mean loss: 0.00109
# Epoch nr 0119 with mean loss: 0.00107
# Epoch nr 0120 with mean loss: 0.00107
# Epoch nr 0121 with mean loss: 0.00104
# Epoch nr 0122 with mean loss: 0.00104
# Epoch nr 0123 with mean loss: 0.00103
# Epoch nr 0124 with mean loss: 0.00101
# Epoch nr 0125 with mean loss: 0.00098
# Epoch nr 0126 with mean loss: 0.00100
# Epoch nr 0127 with mean loss: 0.00099
# Epoch nr 0128 with mean loss: 0.00102
# Epoch nr 0129 with mean loss: 0.00100
# Epoch nr 0130 with mean loss: 0.00098
# Epoch nr 0131 with mean loss: 0.00099
# Epoch nr 0132 with mean loss: 0.00097
# Epoch nr 0133 with mean loss: 0.00096
# Epoch nr 0134 with mean loss: 0.00097
# Epoch nr 0135 with mean loss: 0.00092
# Epoch nr 0136 with mean loss: 0.00095
# Epoch nr 0137 with mean loss: 0.00093
# Epoch nr 0138 with mean loss: 0.00094
# Epoch nr 0139 with mean loss: 0.00095
# Epoch nr 0140 with mean loss: 0.00093
# Epoch nr 0141 with mean loss: 0.00090
# Epoch nr 0142 with mean loss: 0.00090
# Epoch nr 0143 with mean loss: 0.00092
# Epoch nr 0144 with mean loss: 0.00093
# Epoch nr 0145 with mean loss: 0.00091
# Epoch nr 0146 with mean loss: 0.00091
# Epoch nr 0147 with mean loss: 0.00089
# Epoch nr 0148 with mean loss: 0.00089
# Epoch nr 0149 with mean loss: 0.00087
# Epoch nr 0150 with mean loss: 0.00089
# Epoch nr 0151 with mean loss: 0.00087
# Epoch nr 0152 with mean loss: 0.00085
# Epoch nr 0153 with mean loss: 0.00087
# Epoch nr 0154 with mean loss: 0.00088
# Epoch nr 0155 with mean loss: 0.00087
# Epoch nr 0156 with mean loss: 0.00086
# Epoch nr 0157 with mean loss: 0.00087
# Epoch nr 0158 with mean loss: 0.00085
# Epoch nr 0159 with mean loss: 0.00085
# Epoch nr 0160 with mean loss: 0.00084
# Epoch nr 0161 with mean loss: 0.00085
# Epoch nr 0162 with mean loss: 0.00085
# Epoch nr 0163 with mean loss: 0.00085
# Epoch nr 0164 with mean loss: 0.00082
# Epoch nr 0165 with mean loss: 0.00082
# Epoch nr 0166 with mean loss: 0.00083
# Epoch nr 0167 with mean loss: 0.00083
# Epoch nr 0168 with mean loss: 0.00082
# Epoch nr 0169 with mean loss: 0.00082
# Epoch nr 0170 with mean loss: 0.00083
# Epoch nr 0171 with mean loss: 0.00081
# Epoch nr 0172 with mean loss: 0.00082
# Epoch nr 0173 with mean loss: 0.00080
# Epoch nr 0174 with mean loss: 0.00082
# Epoch nr 0175 with mean loss: 0.00081
# Epoch nr 0176 with mean loss: 0.00082
# Epoch nr 0177 with mean loss: 0.00079
# Epoch nr 0178 with mean loss: 0.00080
# Epoch nr 0179 with mean loss: 0.00078
# Epoch nr 0180 with mean loss: 0.00077
# Epoch nr 0181 with mean loss: 0.00075
# Epoch nr 0182 with mean loss: 0.00076
# Epoch nr 0183 with mean loss: 0.00078
# Epoch nr 0184 with mean loss: 0.00079
# Epoch nr 0185 with mean loss: 0.00077
# Epoch nr 0186 with mean loss: 0.00077
# Epoch nr 0187 with mean loss: 0.00077
# Epoch nr 0188 with mean loss: 0.00077
# Epoch nr 0189 with mean loss: 0.00079
# Epoch nr 0190 with mean loss: 0.00076
# Epoch nr 0191 with mean loss: 0.00076
# Epoch nr 0192 with mean loss: 0.00075
# Epoch nr 0193 with mean loss: 0.00077
# Epoch nr 0194 with mean loss: 0.00076
# Epoch nr 0195 with mean loss: 0.00076
# Epoch nr 0196 with mean loss: 0.00077
# Epoch nr 0197 with mean loss: 0.00076
# Epoch nr 0198 with mean loss: 0.00076
# Epoch nr 0199 with mean loss: 0.00072
# Epoch nr 0200 with mean loss: 0.00073
# Epoch nr 0201 with mean loss: 0.00073
# Epoch nr 0202 with mean loss: 0.00072
# Epoch nr 0203 with mean loss: 0.00075
# Epoch nr 0204 with mean loss: 0.00074
# Epoch nr 0205 with mean loss: 0.00072
# Epoch nr 0206 with mean loss: 0.00072
# Epoch nr 0207 with mean loss: 0.00072
# Epoch nr 0208 with mean loss: 0.00072
# Epoch nr 0209 with mean loss: 0.00074
# Epoch nr 0210 with mean loss: 0.00071
# Epoch nr 0211 with mean loss: 0.00072
# Epoch nr 0212 with mean loss: 0.00071
# Epoch nr 0213 with mean loss: 0.00072
# Epoch nr 0214 with mean loss: 0.00071
# Epoch nr 0215 with mean loss: 0.00072
# Epoch nr 0216 with mean loss: 0.00071
# Epoch nr 0217 with mean loss: 0.00070
# Epoch nr 0218 with mean loss: 0.00071
# Epoch nr 0219 with mean loss: 0.00069
# Epoch nr 0220 with mean loss: 0.00070
# Epoch nr 0221 with mean loss: 0.00070
# Epoch nr 0222 with mean loss: 0.00070
# Epoch nr 0223 with mean loss: 0.00072
# Epoch nr 0224 with mean loss: 0.00072
# Epoch nr 0225 with mean loss: 0.00069
# Epoch nr 0226 with mean loss: 0.00068
# Epoch nr 0227 with mean loss: 0.00069
# Epoch nr 0228 with mean loss: 0.00070
# Epoch nr 0229 with mean loss: 0.00071
# Epoch nr 0230 with mean loss: 0.00069
# Epoch nr 0231 with mean loss: 0.00069
# Epoch nr 0232 with mean loss: 0.00070
# Epoch nr 0233 with mean loss: 0.00068
# Epoch nr 0234 with mean loss: 0.00069
# Epoch nr 0235 with mean loss: 0.00068
# Epoch nr 0236 with mean loss: 0.00066
# Epoch nr 0237 with mean loss: 0.00066
# Epoch nr 0238 with mean loss: 0.00067
# Epoch nr 0239 with mean loss: 0.00068
# Epoch nr 0240 with mean loss: 0.00070
# Epoch nr 0241 with mean loss: 0.00068
# Epoch nr 0242 with mean loss: 0.00067
# Epoch nr 0243 with mean loss: 0.00067
# Epoch nr 0244 with mean loss: 0.00067
# Epoch nr 0245 with mean loss: 0.00067
# Epoch nr 0246 with mean loss: 0.00067
# Epoch nr 0247 with mean loss: 0.00069
# Epoch nr 0248 with mean loss: 0.00067
# Epoch nr 0249 with mean loss: 0.00068
# Epoch nr 0250 with mean loss: 0.00066

# %%
# Load training loss
train_loss = np.load(ROOT + '/models/multivariate.npy').tolist()

# %%
# Plot training loss

# Retrieve list of training losses
train_loss_ = [batch_loss for epoch_loss in train_loss for batch_loss in epoch_loss]

# Get a plot of the training loss
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
_ = fig.suptitle('Training loss (multivariate, 3 lags)')
_ = axs[0].plot(train_loss_, '-')
_ = axs[0].set_title('loss ~ batch')
_ = axs[1].plot(np.log10(list(range(1, len(train_loss_)))), np.log10(train_loss_[1:]), '-')
_ = axs[1].set_title('log(loss) ~ log(batch)')
_ = plt.show()

# %%
# Load weigths from disk
ecnet3.load_state_dict(torch.load(ROOT + '/models/univariate.pt'))
# Out:
# <All keys matched successfully>

# %%
# Predict using training data

# Retrieve network object on current device
ecnet3 = ecnet3.to(torch.device('cpu'))

# Predict on whole training dataset
with torch.no_grad():
    # Set the net in evaluation mode
    ecnet3.eval()

    # Define datetime indices for every predicted value
    train_index = train.dataset.index[train.lag:]
    test_index = test.dataset.index[test.lag:]

    # Make predictions on train set
    x_train = torch.cat([train[i].unsqueeze(0) for i in range(len(train))])
    train_pred, _ = ecnet3(x_train[:, :-1, :])
    
    # Make predictions on test set
    x_test = torch.cat([test[i].unsqueeze(0) for i in range(len(test))])
    test_pred, _ = ecnet3(x_test[:, :-1, :])
    
# Cast retrieved forecast as lists
train_pred = train_pred[:, -1, 0].squeeze().numpy()
test_pred = test_pred[:, -1, 0].squeeze().numpy()

# %%
# Rescale output
train_pred = train_pred * (train.max[0] - train.min[0]) + train.min[0]
test_pred = test_pred * (train.max[0] - train.min[0]) + train.min[0]

# %%
# Define datetime -> (true, train, test) dataset for forecasting
forecast = ds[['AEP']].copy().rename(columns={ds.columns[0]: 'true'})
# Add empty columns: train and test
forecast['train'] = np.nan
forecast['test'] = np.nan

# %%
# Fill forecast dataset with train and test data

# Fill training data
forecast.loc[train_index, 'train'] = np.array(train_pred)
# Fill test data
forecast.loc[test_index, 'test'] = np.array(test_pred)
# Check forecast dataset
forecast.head()

# %%
# Plot forecast using training data
fig, ax = plt.subplots(figsize=(15, 5))
_ = ax.set_title('True vs forecasted values (training data)')
_ = ax.plot(forecast.true, '-')
_ = ax.plot(forecast.test, '-', alpha=.7)
_ = ax.plot(forecast.train, '-', alpha=.7)
_ = ax.legend(['True', 'Test', 'Train'], loc='upper right')
_ = plt.show()

# %%
# Zoom in: get only a year aroung 2017-2018
fig, ax = plt.subplots(figsize=(15, 5))
_ = ax.set_title('True vs forecasted values (test data, monthly resolution)')
_ = ax.plot(forecast['2017-01-01 00:00:00':].true, '-')
_ = ax.plot(forecast['2017-01-01 00:00:00':].test, '-', alpha=.7)
_ = ax.legend(['True', 'Test'], loc='upper right')
_ = plt.show()

# %%
# Zoom in: get only a few days
fig, ax = plt.subplots(figsize=(15, 5))
_ = ax.set_title('True vs forecasted values (test data, daily resolution)')
_ = ax.plot(forecast['2017-06-10 00:00:00':'2017-06-20 23:00:00'].true, '-')
_ = ax.plot(forecast['2017-06-10 00:00:00':'2017-06-20 23:00:00'].test, '-', alpha=.7)
_ = ax.legend(['True', 'Test'], loc='upper right')
_ = plt.show()

# %%
# Zoom in: get only a few hours
fig, ax = plt.subplots(figsize=(15, 5))
_ = ax.set_title('True vs forecasted values (test data, hourly resolution)')
_ = ax.plot(forecast['2017-05-10 12:00:00':'2017-05-11 12:00:00'].true, '-')
_ = ax.plot(forecast['2017-05-10 12:00:00':'2017-05-11 12:00:00'].test, '-', alpha=.7)
_ = ax.legend(['True', 'Test'], loc='upper right')
_ = plt.show()
